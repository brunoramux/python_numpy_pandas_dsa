# %% [markdown]
# # <font color='blue'>Data Science Academy - Big Data Real-Time Analytics com Python e Spark</font>
# # <font color='blue'>Capítulo 3</font>

# %% [markdown]
# ****** Este Jupyter Notebook foi atualizado para a versão 3.6.1. da Linguagem Python em 13/06/2017 ******

# %% [markdown]
# ## Gráficos em Python com ggplot

# %%
# %matplotlib inline

# %%
# !pip install ggplot
# Out:
# Requirement already satisfied: ggplot in /Users/dmpm/anaconda/lib/python3.6/site-packages
# Requirement already satisfied: brewer2mpl in /Users/dmpm/anaconda/lib/python3.6/site-packages (from ggplot)
# Requirement already satisfied: cycler in /Users/dmpm/anaconda/lib/python3.6/site-packages (from ggplot)
# Requirement already satisfied: pandas in /Users/dmpm/anaconda/lib/python3.6/site-packages (from ggplot)
# Requirement already satisfied: numpy in /Users/dmpm/anaconda/lib/python3.6/site-packages (from ggplot)
# Requirement already satisfied: matplotlib in /Users/dmpm/anaconda/lib/python3.6/site-packages (from ggplot)
# Requirement already satisfied: patsy>=0.4 in /Users/dmpm/anaconda/lib/python3.6/site-packages (from ggplot)
# Requirement already satisfied: six in /Users/dmpm/anaconda/lib/python3.6/site-packages (from ggplot)
# Requirement already satisfied: scipy in /Users/dmpm/anaconda/lib/python3.6/site-packages (from ggplot)
# Requirement already satisfied: statsmodels in /Users/dmpm/anaconda/lib/python3.6/site-packages (from ggplot)
# Requirement already satisfied: python-dateutil>=2 in /Users/dmpm/anaconda/lib/python3.6/site-packages (from pandas->ggplot)
# Requirement already satisfied: pytz>=2011k in /Users/dmpm/anaconda/lib/python3.6/site-packages (from pandas->ggplot)
# Requirement already satisfied: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=1.5.6 in /Users/dmpm/anaconda/lib/python3.6/site-packages (from matplotlib->ggplot)

# %%
from ggplot import *
# Out:
# /Users/dmpm/anaconda/lib/python3.6/site-packages/ggplot/utils.py:81: FutureWarning: pandas.tslib is deprecated and will be removed in a future version.
# You can access Timestamp as pandas.Timestamp
#   pd.tslib.Timestamp,
# /Users/dmpm/anaconda/lib/python3.6/site-packages/ggplot/stats/smoothers.py:4: FutureWarning: The pandas.lib module is deprecated and will be removed in a future version. These are private functions and can be accessed from pandas._libs.lib instead
#   from pandas.lib import Timestamp
# /Users/dmpm/anaconda/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
print (ggplot(mtcars, aes('mpg', 'qsec')) + \
       geom_point(colour = 'steelblue') + \
       scale_x_continuous(breaks = [10, 20, 30],  \
                          labels = ["Ruim", "Pk", "Bom"]))
# Out:
# <ggplot: (-9223372036556359378)>

# %%
print (ggplot(meat, aes('date','beef')) + \
       geom_line(color = 'black') + \
       scale_x_date(breaks = date_breaks('7 years'), labels = '%b %Y') + \
       scale_y_continuous(labels = 'comma'))
# Out:
# <ggplot: (-9223372036556359392)>

# %%
import matplotlib.pyplot as plt
from matplotlib.dates import YearLocator, DateFormatter
from ggplot import meat
tick_every_n = YearLocator(7)
date_formatter = DateFormatter('%b %Y')
x = meat.date
y = meat.beef
fig, ax = plt.subplots()
ax.plot(x, y, 'black')
ax.xaxis.set_major_locator(tick_every_n)
ax.xaxis.set_major_formatter(date_formatter)
fig.autofmt_xdate()
plt.show()

# %%
print (ggplot(meat, aes('date','beef * 2000')) + \
       geom_line(color = 'coral') + \
       scale_x_date(breaks = date_breaks('36 months'), labels = '%Y') + \
       scale_y_continuous(labels = 'millions'))
# Out:
# <ggplot: (-9223372036555945149)>

# %% [markdown]
# # Fim

# %% [markdown]
# ### Obrigado - Data Science Academy - <a href=http://facebook.com/dsacademy>facebook.com/dsacademybr</a>
