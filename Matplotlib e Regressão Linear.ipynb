# %% [markdown]
# ## Matplotlib e Regressão Linear

# %%
from scipy import stats
import numpy as np
from matplotlib import pyplot as plt

# %%
from IPython.display import Image
Image(url = 'imagens/lreg.png')
# Out:
# <img src="imagens/lreg.png"/>

# %%
# Preços de casas
x = np.array([113, 347, 199, 371, 549, 301, 419, 579])

# %%
# Tamanho de Casas
y = np.array([1119, 1524, 2101, 2232, 2599, 3201, 3687, 4459])

# %%
slope, intercept, r_value, p_value, std_err = stats.linregress(x, y)

# %%
plt.plot(x, y, 'ro', color = 'red')
# Out:
# /var/folders/5z/nms2vp9s0_1dm1130xnk264w0000gn/T/ipykernel_35734/30660529.py:1: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ro" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(x, y, 'ro', color = 'red')

# %%
plt.ylabel('Tamanho da Casa')
plt.xlabel('Preço')
# Out:
# Text(0.5, 0, 'Preço')

# %%
plt.axis([0, 600, 0, 5000])
# Out:
# (np.float64(0.0), np.float64(600.0), np.float64(0.0), np.float64(5000.0))

# %%
# plt.plot(x, y)
plt.plot(x, x * slope + intercept, 'b')

# %%
plt.plot()
plt.show()
